# %% [markdown]
# **String input **

# %%
a=str(input("Enter a string : "))
print(a)

# %% [markdown]
# **way-1 to write print **

# %%
a=int(input("Enter a number : "))
print("you enter number {} with your finger".format(a))

# %% [markdown]
# ** way -2**

# %%
a=54
b=43
print(f"a is {a} and b is {b}")

# %% [markdown]
# ** all about string**

# %%
string =str("dulux")
print(string)
print(string[0:5])
print(len(string))
print(string.upper())
print(string.lower())
print(string.rstrip(":"))
# print(string.replace("powder"))
print(string.split("-"))

print(string.count("u"))
print(string.endswith("...."))
print(string.find("x"))

# %% [markdown]
# string traversing

# %%
str="Tarun Tomar"
for i in str:
  print(i)
