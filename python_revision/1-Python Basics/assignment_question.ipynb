# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("hello world")
# Out:
# hello world

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a=input("enter your name over here :- ")
print(a)
# Out:
# tarun

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a=int(input("Enter the number over here:-"))
if a>0:
    print(f"{a} is positive")
elif a<0:
    print(f"{a} is negative")
else:
    print(f"{a} is zero")
# Out:
# -1 is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a=int(input("Enter the first number over here:-"))
print(a)
b=int(input("Enter the second number over here:-"))
print(b)
c=int(input("Enter the third number over here:-"))
print(c)

if a>b :
    if a>c:
        print(f"{a} is greator then a and b")
    else :
        print(f"{c} is greator then a and b")

else :
    if b>c:
        print(f"{b} is greator then a and c")
    else:
        print(f"{c} is greator then a and b")
# Out:
# 1
# 2
# 5
# 5 is greator then a and b

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
a=int(input("Enter the number for which u want the factorial : "))
print(a)
if(a==0 and a==1):
     print(1)
else:
     factorial=1
     while(a>0):
          factorial=factorial*a
          a=a-1
print(factorial)
# Out:
# 5
# 120

# %%
def factorial(n):
    if(n==0 or n==1):
        return 1
    return n*factorial(n-1)

a=int(input("Enter the no over here : "))
print(factorial(a))
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a=12
b=12.89
c="tarun"
d=True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=2
b=3
print(a,b)
temp=a
a=b
b=temp
print(a,b)
# Out:
# 2 3
# 3 2

# %%
## swap the value using tuple unpacking

a=3
b=4
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 3 4
# 4 3

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
def convert_temp(temp,unit):
  """this function convert temp between celsius and fahrenheit"""
  if unit=="c":
    return (temp*9/5)+32
  elif unit=="f":
    return (temp-32)*5/9
  else:
    return None
print(convert_temp(32,"c"))

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a="tarun"
b="tomar"
print(a+b)
# Out:
# taruntomar

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a=3.13
if (type(a)==bool):
    print("the variable is boolean data type")

elif (type(a)==float):
    print("the variable is float")
elif (type(a)==str):
    print("the variable is string")
else :
    print("the varible is integer")
# Out:
# the variable is float

# %%
## ask from claude

a = input("Enter the value over here: ")

if a.lower() == "true" or a.lower() == "false":
    print("the variable is boolean data type")
else:
    try:
        int(a)
        print("the variable is integer")
    except ValueError:
        try:
            float(a)
            print("the variable is float")
        except ValueError:
            print("the variable is string")

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a=int(input("Enter the number over here :"))
b=int(input("Enter the number over here :"))
addition=a+b
subtraction=a-b
multiplication=a*b
division=a/b
remainder=a%b
print(addition,subtraction,multiplication,division,remainder)
# Out:
# 6 2 8 2.0 0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a=int(input("Enter the number over here :"))
b=int(input("Enter the number over here :"))

print(a==b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# True
# False
# False
# False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a=int(input("Enter the number over here :"))
b=int(input("Enter the number over here :"))

print(a and b)
print(a or b)
print( not b )
# Out:
# 3
# 4
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
# Your code here
a=int(input("Enter the number over here :"))
square=a*a
print(square)
# Out:
# 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
# Your code here
a=int(input("Enter the number over here :"))

if(a%2==0):
    print(f"{a} is even")

else :
    print(f"{a} is odd")
# Out:
# 5 is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
# Your code here
a=int(input("Enter the number over here :"))
sum=0
for i in range (a):
    sum+=i
print(sum)
# Out:
# 10

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
a=(input("Enter the string over here :"))
print(a[::-1])
# Out:
# nurat

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
a = input("Enter the string: ")
b=a[::-1]
print(a==b)
# Out:
# True

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
lst=[1,2,32,453,23,2,4]
lst.sort()
print(lst)
# Out:
# [1, 2, 2, 4, 23, 32, 453]
