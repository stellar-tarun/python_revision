# %% [markdown]
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# >zero division error(dividing by zero)
# >file not found error
# >value error(invalid value)
# >type error

# %% [markdown]
# ** exception handling**

# %%
a=(input("enter the number : "))

try:
  print(a%2)

except Exception as e:
 print(e)

print("some important line of code")
print("this code is end here horry")
# Out:
# not all arguments converted during string formatting
# some important line of code
# this code is end here horry

# %%
a=(input("enter the number : "))

try:
  print(a%2)

except Exception as e:
 print("kuch toh galata likha hai babu moshaye")

print("some important line of code")
print("this code is end here horry")
# Out:
# kuch toh galata likha hai babu moshaye
# some important line of code
# this code is end here horry

# %%
a=(input("enter the number : "))

try:
  print(a%2)

except Exception as e:
 print("kuch toh galata likha hai babu moshaye")

finally:
  print("finally block")

print("some important line of code")
print("this code is end here horry")
# Out:
# kuch toh galata likha hai babu moshaye
# finally block
# some important line of code
# this code is end here horry

# %%
try:
  index=int(input("Enter the number "))
  a=[6,3]
  print(a[index])

except ValueError:
  print("number dalna hai bhai")

except IndexError:
  print("out of index likha hai babu moshaye")
# Out:
# out of index likha hai babu moshaye
