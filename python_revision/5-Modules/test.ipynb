# %% [markdown]
# here we go to package first and then inside the package their another folder that name is mul and inside mul thier is mul file inside the mul file i import the multiply function

# %%
from package.mul.mul import multiply

multiply(5,2)
# Out:
# 10
