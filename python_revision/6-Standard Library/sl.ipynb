# %% [markdown]
# Standard Library Overview
#
# python's standard library is a vast collection of modules and packages that come bundled with python,providing a wide range of functionlities out of the box. here's an overview of some of the most commonly used modules and packages in the python standard library

# %%
import array
arr=array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %% [markdown]
# Random lib

# %%
import random
print(random.randint(1,10)) ## give randome value between the range
# Out:
# 2

# %%
print(random.choice(['apple','banana','cherry']))
# Out:
# apple

# %% [markdown]
# File and Directory Access
#
# OS lib

# %%
import os
print(os.getcwd())
# Out:
# /Users/taruntomar/AI:ML/python_revision/6-Standard Library

# %%
os.mkdir('test_dir') ##if i run this there will be a folder get created

# %% [markdown]
# Function to create a folder

# %%
def folder_create(str):
    return os.mkdir(str)

# %%
folder_create('test_dir')

# %% [markdown]
# high level operations on files and collection of files

# %% [markdown]
# # **Shutil**
#
# create a file with the given name and then copy the content

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %% [markdown]
# data serialization

# %%
import json
data={'name':'tarun','age':21}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))

paresed_Data=json.loads(json_str)
print(paresed_Data)
print(type(paresed_Data))
# Out:
# {"name": "tarun", "age": 21}
# <class 'str'>
# {'name': 'tarun', 'age': 21}
# <class 'dict'>

# %%
import csv

with open('example.csv',mode='w',newline='')as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['tarun',21])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['tarun', '21']

# %% [markdown]
# Date Time

# %%
from datetime import datetime,timedelta
now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-02-26 22:17:46.802204
# 2026-02-25 22:17:46.802204

# %% [markdown]
# time

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1772124585.4746392
# 1772124587.4773371

# %% [markdown]
# Regular Expression

# %%
import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
