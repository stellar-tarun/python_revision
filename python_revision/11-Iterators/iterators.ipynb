# %% [markdown]
# ## Iterators
#
# iterators are advanced python concepts that allow for effiecient looping and memory management.Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Iterator

# %%
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %% [markdown]
# iterate through all the elements

# %%
next(iterator) ##every time i click(Run) it will print elements and then next and then next and so on
# Out:
# 1

# %% [markdown]
# exception handling

# %%
iterator=iter(my_list) ## i write it alone bcoz i have to start this only ones

# %%
try:
    print(next(iterator)) 
except StopIteration: ## when it come to the last element it will print this 
    print("There are no elements in the iterator")
# Out:
# There are no elements in the iterator
