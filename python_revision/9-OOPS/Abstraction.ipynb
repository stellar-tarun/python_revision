# %% [markdown]
# Abstraction

# %% [markdown]
# Abstraction is the concept of hiding trhe complex implementation details and showing only the necessary features of an object. This helps in reducing programming complexity and effort.

# %%
from abc import ABC,abstractmethod

## Abstract class
class Vechicle(ABC):
    def drive(self):
        print("The vehicle is used for driving")
    @abstractmethod
    def start_engine(self): ## by chance kahi par bhi start_engine define nahi kiya toh ye immediatly error show kr dega, and big project me help milti hai
        pass

class Car(Vechicle):
    def start_engine(self):
        print("Car engine started")

def operate_vehicle(vehicle):
    vehicle.start_engine()

car=Car()
operate_vehicle(car)
# Out:
# Car engine started
